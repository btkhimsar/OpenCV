# %% [markdown]
# <a href="https://colab.research.google.com/github/btkhimsar/OpenCV/blob/master/OpenCv%20tutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install open cv
# !pip install opencv-python

# %%
#import open cv in notebook
import cv2

# %%
#read an image
img = cv2.imread(r"C:\Users\Hp\Desktop\image\download.jpg")

# %%
import matplotlib.pyplot as plt

# %%
#display an image
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-23af6c37b3d0> in <module>()
# ----> 1 plt.imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
#get info = h,w and layer
print (img.shape)
# Out:
# (267, 189, 3)

# %%
print("height of this image = ",img.shape[0])
print("weight of this image = ",img.shape[1])
print("Layer of this image = ",img.shape[2])
# Out:
# height of this image =  267

# %%
#0 = black, 1= white

# %%
#convert rgb to gray scale 
#method 1

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img)

# %%
#method 2
img = cv2.imread(r"C:\Users\Hp\Desktop\image\download.jpg",0)
